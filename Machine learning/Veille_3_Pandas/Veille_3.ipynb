# %% [markdown]
# # Veille 3: A la découverte de la librairie Pandas

# %% [markdown]
# ## - Importation de la librairie Pandas

# %%
import pandas as pd

# %% [markdown]
# ## - Création de données :
# Il y a deux principaux objets en pandas : DataFrame et Series.

# %% [markdown]
# #### - DataFrame :
# Un DataFrame est une table. Il contient un tableau d'entrées individuelles, chacune ayant une certaine valeur. Chaque entrée correspond à une ligne (ou enregistrement) et une colonne.

# %%
pd.DataFrame({'Yes':[50., 21.], 'No':[131., 2.]})
# Out:
#     Yes     No
# 0  50.0  131.0
# 1  21.0    2.0

# %% [markdown]
# ##### Les entrées DataFrame ne sont pas limitées aux entiers. On peut avoir d'autres types de données

# %%
pd.DataFrame({'Bod':['Il aime ça.', 'Je code.'], 'Sue':['Bonne journée.', 'Merveilleux']})
# Out:
#            Bod             Sue
# 0  Il aime ça.  Bonne journée.
# 1     Je code.     Merveilleux

# %%
#On peut aussi modifier le nom des index
pd.DataFrame({'Bod':['Il aime ça.', 'Je code.'], 'Sue':['Bonne journée.', 'Merveilleux']}, index = ['Option_A', 'Option'])
# Out:
#                   Bod             Sue
# Option_A  Il aime ça.  Bonne journée.
# Option_B  Il aime ça.     Merveilleux

# %% [markdown]
# #### - Series :
# Une series est une séquence de valeurs de données. Elle est considerée comme une liste, et par essence, elle est représente une seule colonne d'un DataFrame.

# %%
pd.Series([1., 2., 3., 4., 5., 6.])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# ##### On peut attribuer des étiquettes de ligne à une Series de la même manière qu'avec un DataFrame, à l'aide d'un paramètre d'index. Cependant, une Series n'a pas de nom de colonne, elle n'a qu'un seul nom global.

# %%
pd.Series([15.75, 2.85, 501.], index = ['A', 'B', 'C'], name = 'Chiffres')
# Out:
# A     15.75
# B      2.85
# C    501.00
# Name: Chiffres, dtype: float64

# %% [markdown]
# ### - Lecture de fichiers de données (Reading data files) :
# Un fichier CSV est un tableau de valeurs séparées par des virgules. D'où le nom : "Comma-Separated Values", ou CSV.

# %%
#Utilisation de la fonction pd.read_csv() pour lire les données (du fichier CSV) dans un DataFrame
Lecture = pd.read_csv('C:/Users/Usuario/Documents/Dossier L3/ODC_FORMATION/Veille_3_Pandas/covid.csv')
Lecture
# Out:
#      Country/Region      Continent   Population  TotalCases  NewCases  \
# 0               USA  North America  3.31198e+08     5032179       NaN
# 1            Brazil  South America  2.12711e+08     2917562       NaN
# ..              ...            ...          ...         ...       ...
# 207    Vatican City         Europe  8.01000e+02          12       NaN
# 208  Western Sahara         Africa  5.98682e+05          10       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0       162804.0        NaN       2576668.0           NaN    2292707.0
# 1        98644.0        NaN       2047660.0           NaN     771258.0
# ..           ...        ...             ...           ...          ...
# 207          NaN        NaN            12.0           NaN          0.0
# 208          0.0        NaN             8.0           NaN          0.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0             18296.0           15194.0          492.0  63139605.0
# 1              8318.0           13716.0          464.0  13206188.0
# ..                ...               ...            ...         ...
# 207               NaN           14981.0            NaN         NaN
# 208               NaN              17.0            0.0         NaN
#
#      Tests/1M pop WHO Region
# 0        190640.0   Americas
# 1         62085.0   Americas
# ..            ...        ...
# 207           NaN     Europe
# 208           NaN     Africa
#
# [209 rows x 16 columns]

# %%
#On utilise l'attribut shape pour vérifier la taille du DataFrame
Lecture.shape
# Out:
# (209, 16)

# %%
#On utilise la fonction head() pour afficher les 5 premières lignes du DataFrame
Lecture.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# 1            8318.0           13716.0          464.0  13206188.0
# 2            8944.0            1466.0           30.0  22149351.0
# 3            2300.0            5974.0          100.0  29716907.0
# 4             539.0            9063.0          162.0   3149807.0
#
#    Tests/1M pop      WHO Region
# 0      190640.0        Americas
# 1       62085.0        Americas
# 2       16035.0  South-EastAsia
# 3      203623.0          Europe
# 4       53044.0          Africa

# %%
#On peut utiliser l'attribut index_col pour modifier l'indexation automatique en une colonne du DataFrame en donnant son indexe
Lecture = pd.read_csv('C:/Users/Usuario/Documents/Dossier L3/ODC_FORMATION/Veille_3_Pandas/covid.csv', index_col = 1)
Lecture.head()
# Out:
#               Country/Region    Population  TotalCases  NewCases  TotalDeaths  \
# Continent
# North America            USA  3.311981e+08     5032179       NaN     162804.0
# South America         Brazil  2.127107e+08     2917562       NaN      98644.0
# Asia                   India  1.381345e+09     2025409       NaN      41638.0
# Europe                Russia  1.459409e+08      871894       NaN      14606.0
# Africa          South Africa  5.938157e+07      538184       NaN       9604.0
#
#                NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Continent
# North America        NaN       2576668.0           NaN    2292707.0
# South America        NaN       2047660.0           NaN     771258.0
# Asia                 NaN       1377384.0           NaN     606387.0
# Europe               NaN        676357.0           NaN     180931.0
# Africa               NaN        387316.0           NaN     141264.0
#
#                Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# Continent
# North America           18296.0           15194.0          492.0  63139605.0
# South America            8318.0           13716.0          464.0  13206188.0
# Asia                     8944.0            1466.0           30.0  22149351.0
# Europe                   2300.0            5974.0          100.0  29716907.0
# Africa                    539.0            9063.0          162.0   3149807.0
#
#                Tests/1M pop      WHO Region
# Continent
# North America      190640.0        Americas
# South America       62085.0        Americas
# Asia                16035.0  South-EastAsia
# Europe             203623.0          Europe
# Africa              53044.0          Africa

# %% [markdown]
# ## - Indexation, sélection et affectation (Indexing, selecting, assigneting) :

# %% [markdown]
# ### - Introduction :

# %%
Lecture = pd.read_csv('C:/Users/Usuario/Documents/Dossier L3/ODC_FORMATION/Veille_3_Pandas/covid.csv', index_col = 1)
pd.set_option("display.max_rows", 5)
Lecture
# Out:
#                Country/Region   Population  TotalCases  NewCases  TotalDeaths  \
# Continent
# North America             USA  3.31198e+08     5032179       NaN     162804.0
# South America          Brazil  2.12711e+08     2917562       NaN      98644.0
# ...                       ...          ...         ...       ...          ...
# Europe           Vatican City  8.01000e+02          12       NaN          NaN
# Africa         Western Sahara  5.98682e+05          10       NaN          0.0
#
#                NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Continent
# North America        NaN       2576668.0           NaN    2292707.0
# South America        NaN       2047660.0           NaN     771258.0
# ...                  ...             ...           ...          ...
# Europe               NaN            12.0           NaN          0.0
# Africa               NaN             8.0           NaN          0.0
#
#                Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# Continent
# North America           18296.0           15194.0          492.0  63139605.0
# South America            8318.0           13716.0          464.0  13206188.0
# ...                         ...               ...            ...         ...
# Europe                      NaN           14981.0            NaN         NaN
# Africa                      NaN              17.0            0.0         NaN
#
#                Tests/1M pop WHO Region
# Continent
# North America      190640.0   Americas
# South America       62085.0   Americas
# ...                     ...        ...
# Europe                  NaN     Europe
# Africa                  NaN     Africa
#
# [209 rows x 15 columns]

# %% [markdown]
# ### - Accesseurs natifs (Native accessors) :

# %%
#Affichage de la colonne Continent
Lecture.Continent
# Out:
# 0      North America
# 1      South America
# 2               Asia
# 3             Europe
# 4             Africa
#            ...
# 204    North America
# 205    North America
# 206    South America
# 207           Europe
# 208           Africa
# Name: Continent, Length: 209, dtype: object

# %%
#Affichage de la colonne Continent en le passant en indexe
Lecture['Continent']
# Out:
# 0      North America
# 1      South America
# 2               Asia
# 3             Europe
# 4             Africa
#            ...
# 204    North America
# 205    North America
# 206    South America
# 207           Europe
# 208           Africa
# Name: Continent, Length: 209, dtype: object

# %%
#Affichage d'un élement de la colonne Continent en passant son num_indexe
Lecture['Continent'][206]
# Out:
# 'South America'

# %% [markdown]
# ### - Sélection basée sur l'index :
# On utilise l'opérateur d'accès : iloc.

# %%
#Affichage de la ligne (enregistrement) i de toutes les colonnes avec l'opérateur iloc[i]
Lecture.iloc[0]
# Out:
# Country/Region                USA
# Continent           North America
# Population            331198130.0
# TotalCases                5032179
# NewCases                      NaN
# TotalDeaths              162804.0
# NewDeaths                     NaN
# TotalRecovered          2576668.0
# NewRecovered                  NaN
# ActiveCases             2292707.0
# Serious,Critical          18296.0
# Tot Cases/1M pop          15194.0
# Deaths/1M pop               492.0
# TotalTests             63139605.0
# Tests/1M pop             190640.0
# WHO Region               Americas
# Name: 0, dtype: object

# %%
#Affichage de toutes les lignes de la première colonne
Lecture.iloc[:, 0]
# Out:
# 0                        USA
# 1                     Brazil
# 2                      India
# 3                     Russia
# 4               South Africa
#                ...
# 204               Montserrat
# 205    Caribbean Netherlands
# 206         Falkland Islands
# 207             Vatican City
# 208           Western Sahara
# Name: Country/Region, Length: 209, dtype: object

# %%
#Affichage de la ligne 200 à la ligne 206 (206 est exclus) de la deuxième colonne
Lecture.iloc[200:206, 1]
# Out:
# 200             Asia
# 201    North America
# 202    North America
# 203    North America
# 204    North America
# 205    North America
# Name: Continent, dtype: object

# %%
#Affichage des 5 dernièrres lignes de la deuxième colonne
Lecture.iloc[-5:, 1]
# Out:
# 204    North America
# 205    North America
# 206    South America
# 207           Europe
# 208           Africa
# Name: Continent, dtype: object

# %%
#Renvoie de la liste correspondante en passant en paramètre num_indexe des lignes à afficher avec iloc[[i, j, k], num_indexe_col]
Lecture.iloc[[200, 203, 208], 1]
# Out:
# 200             Asia
# 203    North America
# 208           Africa
# Name: Continent, dtype: object

# %%
#Affichage de la ligne 1 à la ligne 12 par pas de 2(12 est exclus) de la deuxième colonne
Lecture.iloc[1:12:2, 1]
# Out:
# 1     South America
# 3            Europe
# 5     North America
# 7     South America
# 9            Europe
# 11           Europe
# Name: Continent, dtype: object

# %% [markdown]
# ### - Sélection basée sur l'index :
# On utilise l'opérateur d'accès : loc.

# %%
#Affichage de la valeur de la donnée à l'indexe i dans la colonne (etiquette) spécifiée avec loc[i, 'nom_col']
Lecture.loc[3, 'Continent']
# Out:
# 'Europe'

# %%
#Affichage de toutes les valeurs des données dans les colonne ('Continent', 'Country/Region', 'Population') 
Lecture.loc[:, ['Continent', 'Country/Region', 'Population']]
# Out:
#          Continent         Country/Region    Population
# 0    North America                    USA  3.311981e+08
# 1    South America                 Brazil  2.127107e+08
# 2             Asia                  India  1.381345e+09
# 3           Europe                 Russia  1.459409e+08
# 4           Africa           South Africa  5.938157e+07
# ..             ...                    ...           ...
# 204  North America             Montserrat  4.992000e+03
# 205  North America  Caribbean Netherlands  2.624700e+04
# 206  South America       Falkland Islands  3.489000e+03
# 207         Europe           Vatican City  8.010000e+02
# 208         Africa         Western Sahara  5.986820e+05
#
# [209 rows x 3 columns]

# %% [markdown]
# ### - Manipulation de l'indice :

# %%
#Affichage du DataFrame avec Continent comme colonne d'indice
Lecture.set_index("Continent")
# Out:
#                Country/Region   Population  TotalCases  NewCases  TotalDeaths  \
# Continent
# North America             USA  3.31198e+08     5032179       NaN     162804.0
# South America          Brazil  2.12711e+08     2917562       NaN      98644.0
# ...                       ...          ...         ...       ...          ...
# Europe           Vatican City  8.01000e+02          12       NaN          NaN
# Africa         Western Sahara  5.98682e+05          10       NaN          0.0
#
#                NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Continent
# North America        NaN       2576668.0           NaN    2292707.0
# South America        NaN       2047660.0           NaN     771258.0
# ...                  ...             ...           ...          ...
# Europe               NaN            12.0           NaN          0.0
# Africa               NaN             8.0           NaN          0.0
#
#                Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# Continent
# North America           18296.0           15194.0          492.0  63139605.0
# South America            8318.0           13716.0          464.0  13206188.0
# ...                         ...               ...            ...         ...
# Europe                      NaN           14981.0            NaN         NaN
# Africa                      NaN              17.0            0.0         NaN
#
#                Tests/1M pop WHO Region
# Continent
# North America      190640.0   Americas
# South America       62085.0   Americas
# ...                     ...        ...
# Europe                  NaN     Europe
# Africa                  NaN     Africa
#
# [209 rows x 15 columns]

# %% [markdown]
# ### - Sélection conditionnelle :

# %%
#Affiche true lorsque l'enregistrement contient la valeur 'Africa' dans cas contraire false
Lecture.Continent == 'Africa'
# Out:
# 0      False
# 1      False
#        ...
# 207    False
# 208     True
# Name: Continent, Length: 209, dtype: bool

# %%
#Affichage de l'enregistrement contenant la valeur 'Africa' de la colonne Continent
Lecture.loc[Lecture.Continent == 'Africa']
# Out:
#      Country/Region Continent   Population  TotalCases  NewCases  TotalDeaths  \
# 4      South Africa    Africa  5.93816e+07      538184       NaN       9604.0
# 26            Egypt    Africa  1.02517e+08       95006       NaN       4951.0
# ..              ...       ...          ...         ...       ...          ...
# 184      Seychelles    Africa  9.84080e+04         126       NaN          NaN
# 208  Western Sahara    Africa  5.98682e+05          10       NaN          0.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 4          NaN        387316.0           NaN     141264.0             539.0
# 26         NaN         48898.0           NaN      41157.0              41.0
# ..         ...             ...           ...          ...               ...
# 184        NaN           124.0           NaN          0.0               NaN
# 208        NaN             8.0           NaN          0.0               NaN
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  \
# 4              9063.0          162.0   3149807.0       53044.0
# 26              927.0           48.0    135000.0        1317.0
# ..                ...            ...         ...           ...
# 184            1280.0            NaN         NaN           NaN
# 208              17.0            0.0         NaN           NaN
#
#                WHO Region
# 4                  Africa
# 26   EasternMediterranean
# ..                    ...
# 184                Africa
# 208                Africa
#
# [57 rows x 16 columns]

# %%
#Affichage de l'enregistrement contenant la valeur 'Africa' de colonne Continent et TotalCases  <= 300
Lecture.loc[(Lecture.Continent == 'Africa') & (Lecture.TotalCases <= 300)]
# Out:
#      Country/Region Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 169         Eritrea    Africa   3551175.0         282       NaN          NaN
# 184      Seychelles    Africa     98408.0         126       NaN          NaN
# 208  Western Sahara    Africa    598682.0          10       NaN          0.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 169        NaN           225.0           NaN         57.0               NaN
# 184        NaN           124.0           NaN          0.0               NaN
# 208        NaN             8.0           NaN          0.0               NaN
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop WHO Region
# 169              79.0            NaN         NaN           NaN     Africa
# 184            1280.0            NaN         NaN           NaN     Africa
# 208              17.0            0.0         NaN           NaN     Africa

# %%
#Affichage de l'enregistrement contenant la valeur 'Africa' de colonne Continent ou TotalCases  <= 300
Lecture.loc[(Lecture.Continent == 'Africa') | (Lecture.TotalCases <= 300)]
# Out:
#      Country/Region Continent   Population  TotalCases  NewCases  TotalDeaths  \
# 4      South Africa    Africa  5.93816e+07      538184       NaN       9604.0
# 26            Egypt    Africa  1.02517e+08       95006       NaN       4951.0
# ..              ...       ...          ...         ...       ...          ...
# 207    Vatican City    Europe  8.01000e+02          12       NaN          NaN
# 208  Western Sahara    Africa  5.98682e+05          10       NaN          0.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 4          NaN        387316.0           NaN     141264.0             539.0
# 26         NaN         48898.0           NaN      41157.0              41.0
# ..         ...             ...           ...          ...               ...
# 207        NaN            12.0           NaN          0.0               NaN
# 208        NaN             8.0           NaN          0.0               NaN
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  \
# 4              9063.0          162.0   3149807.0       53044.0
# 26              927.0           48.0    135000.0        1317.0
# ..                ...            ...         ...           ...
# 207           14981.0            NaN         NaN           NaN
# 208              17.0            0.0         NaN           NaN
#
#                WHO Region
# 4                  Africa
# 26   EasternMediterranean
# ..                    ...
# 207                Europe
# 208                Africa
#
# [95 rows x 16 columns]

# %% [markdown]
# #####  Pandas est livré avec quelques sélecteurs conditionnels intégrés, dont : isin, isnull, notnull.

# %%
#Permet de faire la sélection des enregistrements contenant 'Africa' et 'Europe' dans la colonne Continent  
Lecture.loc[Lecture.Continent.isin(['Africa', 'Europe'])]
# Out:
#      Country/Region Continent   Population  TotalCases  NewCases  TotalDeaths  \
# 3            Russia    Europe  1.45941e+08      871894       NaN      14606.0
# 4      South Africa    Africa  5.93816e+07      538184       NaN       9604.0
# ..              ...       ...          ...         ...       ...          ...
# 207    Vatican City    Europe  8.01000e+02          12       NaN          NaN
# 208  Western Sahara    Africa  5.98682e+05          10       NaN          0.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 3          NaN        676357.0           NaN     180931.0            2300.0
# 4          NaN        387316.0           NaN     141264.0             539.0
# ..         ...             ...           ...          ...               ...
# 207        NaN            12.0           NaN          0.0               NaN
# 208        NaN             8.0           NaN          0.0               NaN
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop WHO Region
# 3              5974.0          100.0  29716907.0      203623.0     Europe
# 4              9063.0          162.0   3149807.0       53044.0     Africa
# ..                ...            ...         ...           ...        ...
# 207           14981.0            NaN         NaN           NaN     Europe
# 208              17.0            0.0         NaN           NaN     Africa
#
# [105 rows x 16 columns]

# %%
#Permet de faire la sélection des enregistrements contenant NaN (vides) dans la colonne NewDeaths  
Lecture.loc[Lecture.NewDeaths.isnull()]
# Out:
#      Country/Region      Continent   Population  TotalCases  NewCases  \
# 0               USA  North America  3.31198e+08     5032179       NaN
# 1            Brazil  South America  2.12711e+08     2917562       NaN
# ..              ...            ...          ...         ...       ...
# 207    Vatican City         Europe  8.01000e+02          12       NaN
# 208  Western Sahara         Africa  5.98682e+05          10       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0       162804.0        NaN       2576668.0           NaN    2292707.0
# 1        98644.0        NaN       2047660.0           NaN     771258.0
# ..           ...        ...             ...           ...          ...
# 207          NaN        NaN            12.0           NaN          0.0
# 208          0.0        NaN             8.0           NaN          0.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0             18296.0           15194.0          492.0  63139605.0
# 1              8318.0           13716.0          464.0  13206188.0
# ..                ...               ...            ...         ...
# 207               NaN           14981.0            NaN         NaN
# 208               NaN              17.0            0.0         NaN
#
#      Tests/1M pop WHO Region
# 0        190640.0   Americas
# 1         62085.0   Americas
# ..            ...        ...
# 207           NaN     Europe
# 208           NaN     Africa
#
# [206 rows x 16 columns]

# %%
#Permet de faire la sélection des enregistrements non vides dans la colonne NewDeaths  
Lecture.loc[Lecture.NewDeaths.notnull()]
# Out:
#    Country/Region      Continent   Population  TotalCases  NewCases  \
# 5          Mexico  North America  1.29066e+08      462690    6590.0
# 28        Bolivia  South America  1.16885e+07       86423    1282.0
# 72       S. Korea           Asia  5.12737e+07       14519      20.0
#
#     TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 5       50517.0      819.0        308848.0        4140.0     103325.0
# 28       3465.0       80.0         27373.0         936.0      55585.0
# 72        303.0        0.0         13543.0          42.0        673.0
#
#     Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 5             3987.0            3585.0          391.0   1056915.0
# 28              71.0            7394.0          296.0    183583.0
# 72              18.0             283.0            6.0   1613652.0
#
#     Tests/1M pop      WHO Region
# 5         8189.0        Americas
# 28       15706.0        Americas
# 72       31471.0  WesternPacific

# %% [markdown]
# ### - Assignation de donnée :

# %%
#Ajoute une nouvelle colonne Critic et attribut à tous ces enregistrement la valeur 'everyone'
Lecture['Critic'] = 'everyone'
Lecture.Critic
# Out:
# 0      everyone
# 1      everyone
#          ...
# 207    everyone
# 208    everyone
# Name: Critic, Length: 209, dtype: object

# %%
len(Lecture)
# Out:
# 209

# %%
#Ajoute une nouvelle colonne index_backwards et attribut à tous ces enregistrement une valeur de 209 à 1
Lecture['index_backwards'] = range(len(Lecture), 0, -1)
Lecture['index_backwards']
# Out:
# 0      209
# 1      208
#       ...
# 207      2
# 208      1
# Name: index_backwards, Length: 209, dtype: int64

# %% [markdown]
# ## - Fonctions récapitulatives et cartes :

# %% [markdown]
# ### - Introduction :

# %%
import numpy as np
Lecture = pd.read_csv('C:/Users/Usuario/Documents/Dossier L3/ODC_FORMATION/Veille_3_Pandas/covid.csv', index_col = 1)
pd.set_option("display.max_rows", 5)
Lecture
# Out:
#                Country/Region   Population  TotalCases  NewCases  TotalDeaths  \
# Continent
# North America             USA  3.31198e+08     5032179       NaN     162804.0
# South America          Brazil  2.12711e+08     2917562       NaN      98644.0
# ...                       ...          ...         ...       ...          ...
# Europe           Vatican City  8.01000e+02          12       NaN          NaN
# Africa         Western Sahara  5.98682e+05          10       NaN          0.0
#
#                NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Continent
# North America        NaN       2576668.0           NaN    2292707.0
# South America        NaN       2047660.0           NaN     771258.0
# ...                  ...             ...           ...          ...
# Europe               NaN            12.0           NaN          0.0
# Africa               NaN             8.0           NaN          0.0
#
#                Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# Continent
# North America           18296.0           15194.0          492.0  63139605.0
# South America            8318.0           13716.0          464.0  13206188.0
# ...                         ...               ...            ...         ...
# Europe                      NaN           14981.0            NaN         NaN
# Africa                      NaN              17.0            0.0         NaN
#
#                Tests/1M pop WHO Region
# Continent
# North America      190640.0   Americas
# South America       62085.0   Americas
# ...                     ...        ...
# Europe                  NaN     Europe
# Africa                  NaN     Africa
#
# [209 rows x 15 columns]

# %% [markdown]
# ### - Fonctions récapitulatives (Summary founction) :
# On a describe() : elle génère un résumé de haut niveau des attributs de la colonne donnée. Il est sensible au type, ce qui signifie que sa sortie change en fonction du type de données de l'entrée. Elle donne une description statistique de la colonne donnée

# %%
#La sortie ci-dessous n'a de sens que pour les données numériques
Lecture.Population.describe()
# Out:
# count    2.08000e+02
# mean     3.04155e+07
#             ...
# 75%      2.57561e+07
# max      1.38134e+09
# Name: Population, Length: 8, dtype: float64

# %%
#La sortie ci-dessous n'a de sens que pour les chaines de caractères (String)
Lecture.Continent.describe()
# Out:
# count        208
# unique         6
# top       Africa
# freq          57
# Name: Continent, dtype: object

# %% [markdown]
# ##### Pour obtenir des statistiques récapitulatives simples et particulières sur une colonne dans un DataFrame ou une Series, il existe généralement quelques fonctions pandas utilent qui permettent de le faire : mean(), unique(), value_counts()

# %%
#mean() = Renvoie la moyenne de la colonne specifiée (mean est utilisé uniquement avec les données numériques)
Lecture.Population.mean()
# Out:
# 30415486.971153848

# %%
#unique() = Renvoie les valeurs uniques contenues dans la colonne specifiée
Lecture.Continent.unique()
# Out:
# array(['North America', 'South America', 'Asia', 'Europe', 'Africa',
#        'Australia/Oceania', nan], dtype=object)

# %%
#value_counts() = Renvoie une série contenant le nombre de valeurs uniques dans une colonne specifique.
Lecture.NewDeaths.value_counts()
# Out:
# 819.0    1
# 80.0     1
# 0.0      1
# Name: NewDeaths, dtype: int64

# %% [markdown]
# ### - Maps :
# En science des données, nous avons souvent besoin de créer de nouvelles représentations à partir de données existantes ou de transformer des données du format dans lequel elles se trouvent actuellement au format dans lequel nous voulons qu'elles soient plus tard. Les cartes (Maps) sont ce qui gère ce travail. Il existe deux méthodes de mappage que vous utiliserez souvent : map(), apply().

# %%
essai_1 = Lecture.Population.mean()
Lecture.Population.map(lambda p : p - essai_1)
# Out:
# 0      3.00783e+08
# 1      1.82295e+08
#           ...
# 207   -3.04147e+07
# 208   -2.98168e+07
# Name: Population, Length: 209, dtype: float64

# %%
essai_2 = Lecture.TotalCases.mean()
def funct_TCases(row):
    row.TotalCases = row.TotalCases - essai_2
    return row
a = Lecture.apply(funct_TCases, axis = 'columns')
a
# Out:
#      Country/Region      Continent   Population   TotalCases  NewCases  \
# 0               USA  North America  3.31198e+08  4.94046e+06       NaN
# 1            Brazil  South America  2.12711e+08  2.82584e+06       NaN
# ..              ...            ...          ...          ...       ...
# 207    Vatican City         Europe  8.01000e+02 -9.17065e+04       NaN
# 208  Western Sahara         Africa  5.98682e+05 -9.17085e+04       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0       162804.0        NaN       2576668.0           NaN    2292707.0
# 1        98644.0        NaN       2047660.0           NaN     771258.0
# ..           ...        ...             ...           ...          ...
# 207          NaN        NaN            12.0           NaN          0.0
# 208          0.0        NaN             8.0           NaN          0.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0             18296.0           15194.0          492.0  63139605.0
# 1              8318.0           13716.0          464.0  13206188.0
# ..                ...               ...            ...         ...
# 207               NaN           14981.0            NaN         NaN
# 208               NaN              17.0            0.0         NaN
#
#      Tests/1M pop WHO Region
# 0        190640.0   Americas
# 1         62085.0   Americas
# ..            ...        ...
# 207           NaN     Europe
# 208           NaN     Africa
#
# [209 rows x 16 columns]

# %%
a.head(1)
# Out:
#   Country/Region      Continent   Population   TotalCases  NewCases  \
# 0            USA  North America  3.31198e+08  4.94046e+06       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
#
#    Tests/1M pop WHO Region
# 0      190640.0   Americas

# %%
#Pour redefinir notre colonne TotalCases, on peut faire le mapping
essai_2 = Lecture.TotalCases.mean()
Lecture.TotalCases - essai_2
# Out:
# 0      4.94046e+06
# 1      2.82584e+06
#           ...
# 207   -9.17065e+04
# 208   -9.17085e+04
# Name: TotalCases, Length: 209, dtype: float64

# %%
Lecture.rename(columns = {'Country/Region': 'Country_Region'}, inplace = True)

# %%
Lecture
# Out:
#                       Country_Region   Population  TotalCases  NewCases  \
# Continent
# North America                    USA  3.31198e+08     5032179       NaN
# South America                 Brazil  2.12711e+08     2917562       NaN
# Asia                           India  1.38134e+09     2025409       NaN
# Europe                        Russia  1.45941e+08      871894       NaN
# Africa                  South Africa  5.93816e+07      538184       NaN
# ...                              ...          ...         ...       ...
# North America             Montserrat  4.99200e+03          13       NaN
# North America  Caribbean Netherlands  2.62470e+04          13       NaN
# South America       Falkland Islands  3.48900e+03          13       NaN
# Europe                  Vatican City  8.01000e+02          12       NaN
# Africa                Western Sahara  5.98682e+05          10       NaN
#
#                TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# Continent
# North America     162804.0        NaN       2576668.0           NaN
# South America      98644.0        NaN       2047660.0           NaN
# Asia               41638.0        NaN       1377384.0           NaN
# Europe             14606.0        NaN        676357.0           NaN
# Africa              9604.0        NaN        387316.0           NaN
# ...                    ...        ...             ...           ...
# North America          0.0        NaN            10.0           NaN
# North America          NaN        NaN             7.0           NaN
# South America          NaN        NaN            13.0           NaN
# Europe                 NaN        NaN            12.0           NaN
# Africa                 0.0        NaN             8.0           NaN
#
#                ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  \
# Continent
# North America    2292707.0           18296.0           15194.0          492.0
# South America     771258.0            8318.0           13716.0          464.0
# Asia              606387.0            8944.0            1466.0           30.0
# Europe            180931.0            2300.0            5974.0          100.0
# Africa            141264.0             539.0            9063.0          162.0
# ...                    ...               ...               ...            ...
# North America          0.0               NaN            2604.0          200.0
# North America          6.0               NaN             495.0            NaN
# South America          0.0               NaN            3726.0            NaN
# Europe                 0.0               NaN           14981.0            NaN
# Africa                 0.0               NaN              17.0            0.0
#
#                TotalTests  Tests/1M pop      WHO Region
# Continent
# North America  63139605.0      190640.0        Americas
# South America  13206188.0       62085.0        Americas
# Asia           22149351.0       16035.0  South-EastAsia
# Europe         29716907.0      203623.0          Europe
# Africa          3149807.0       53044.0          Africa
# ...                   ...           ...             ...
# North America        61.0       12220.0             NaN
# North America       424.0       16154.0             NaN
# South America      1816.0      520493.0             NaN
# Europe                NaN           NaN          Europe
# Africa                NaN           NaN          Africa
#
# [209 rows x 15 columns]

# %%
#Concatenetion de deux Series de longueur égale
Lecture.Continent +"  ->  "+ Lecture.Country_Region
# Out:
# 0          North America  ->  USA
# 1       South America  ->  Brazil
#                   ...
# 207      Europe  ->  Vatican City
# 208    Africa  ->  Western Sahara
# Length: 209, dtype: object

# %% [markdown]
# ## - Regroupement et tri

# %% [markdown]
# ### - Groupwise analysis (Analyse par groupe) :

# %%
import numpy as np
Lecture = pd.read_csv('C:/Users/Usuario/Documents/Dossier L3/ODC_FORMATION/Veille_3_Pandas/covid.csv', index_col = 1)
pd.set_option("display.max_rows", 20)
Lecture.rename(columns = {'Country/Region': 'Country_Region'}, inplace = True)
Lecture
# Out:
#                       Country_Region   Population  TotalCases  NewCases  \
# Continent
# North America                    USA  3.31198e+08     5032179       NaN
# South America                 Brazil  2.12711e+08     2917562       NaN
# Asia                           India  1.38134e+09     2025409       NaN
# Europe                        Russia  1.45941e+08      871894       NaN
# Africa                  South Africa  5.93816e+07      538184       NaN
# ...                              ...          ...         ...       ...
# North America             Montserrat  4.99200e+03          13       NaN
# North America  Caribbean Netherlands  2.62470e+04          13       NaN
# South America       Falkland Islands  3.48900e+03          13       NaN
# Europe                  Vatican City  8.01000e+02          12       NaN
# Africa                Western Sahara  5.98682e+05          10       NaN
#
#                TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# Continent
# North America     162804.0        NaN       2576668.0           NaN
# South America      98644.0        NaN       2047660.0           NaN
# Asia               41638.0        NaN       1377384.0           NaN
# Europe             14606.0        NaN        676357.0           NaN
# Africa              9604.0        NaN        387316.0           NaN
# ...                    ...        ...             ...           ...
# North America          0.0        NaN            10.0           NaN
# North America          NaN        NaN             7.0           NaN
# South America          NaN        NaN            13.0           NaN
# Europe                 NaN        NaN            12.0           NaN
# Africa                 0.0        NaN             8.0           NaN
#
#                ActiveCases  Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  \
# Continent
# North America    2292707.0           18296.0           15194.0          492.0
# South America     771258.0            8318.0           13716.0          464.0
# Asia              606387.0            8944.0            1466.0           30.0
# Europe            180931.0            2300.0            5974.0          100.0
# Africa            141264.0             539.0            9063.0          162.0
# ...                    ...               ...               ...            ...
# North America          0.0               NaN            2604.0          200.0
# North America          6.0               NaN             495.0            NaN
# South America          0.0               NaN            3726.0            NaN
# Europe                 0.0               NaN           14981.0            NaN
# Africa                 0.0               NaN              17.0            0.0
#
#                TotalTests  Tests/1M pop      WHO Region
# Continent
# North America  63139605.0      190640.0        Americas
# South America  13206188.0       62085.0        Americas
# Asia           22149351.0       16035.0  South-EastAsia
# Europe         29716907.0      203623.0          Europe
# Africa          3149807.0       53044.0          Africa
# ...                   ...           ...             ...
# North America        61.0       12220.0             NaN
# North America       424.0       16154.0             NaN
# South America      1816.0      520493.0             NaN
# Europe                NaN           NaN          Europe
# Africa                NaN           NaN          Africa
#
# [209 rows x 15 columns]

# %%
#Grouper le cas TotalDeaths en fonction de du nombre de compte
Lecture.groupby('TotalDeaths').TotalDeaths.count()
# Out:
# TotalDeaths
# 0.0         7
# 0.0         3
# 0.0         5
# 0.0         1
# 0.0         3
#            ..
# 41638.0     1
# 46413.0     1
# 50517.0     1
# 98644.0     1
# 162804.0    1
# Name: TotalDeaths, Length: 150, dtype: int64

# %%
#Groupement de cas total en foction du minimum des cas total de mort
Lecture.groupby('TotalCases').TotalDeaths.min()
# Out:
# TotalCases
# 10              0.0
# 12              NaN
# 13              0.0
# 14              NaN
# 17              NaN
#              ...
# 538184       9604.0
# 871894      14606.0
# 2025409     41638.0
# 2917562     98644.0
# 5032179    162804.0
# Name: TotalDeaths, Length: 206, dtype: float64

# %%
#Renvoie le nombre de population correspondant à la première occurence de chaque continent dans la colonne Continent
Lecture.groupby('Continent').apply(lambda df : df.Population.iloc[0])
# Out:
# Continent
# Africa               5.93816e+07
# Asia                 1.38134e+09
# Australia/Oceania    2.55289e+07
# Europe               1.45941e+08
# North America        3.31198e+08
# South America        2.12711e+08
# dtype: float64

# %%
# idxmax() = renvoie l'index de retour de la première occurrence du maximum sur l'axe demandé.
#Permet de grouper les colonnes Continent et TotalCases en fonction de la première occurrence du maximum sur l'axe Population
Lecture.groupby(['Continent', 'TotalCases']).apply(lambda df : df.loc[df.Population.idxmax()]).tail(20)
# Out:
#                                                      0 Country_Region  \
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop      13793.0            NaN
#                          Deaths/1M pop           619.0            NaN
#                          TotalTests          2493429.0            NaN
#                          Tests/1M pop          75521.0            NaN
#                          WHO Region           Americas            NaN
#               2917562    Country_Region         Brazil            NaN
#                          Population        212710692.0            NaN
#                          TotalCases            2917562            NaN
#                          NewCases                  NaN            NaN
#                          TotalDeaths           98644.0            NaN
#                          NewDeaths                 NaN            NaN
#                          TotalRecovered      2047660.0            NaN
#                          NewRecovered              NaN            NaN
#                          ActiveCases          771258.0            NaN
#                          Serious,Critical       8318.0            NaN
#                          Tot Cases/1M pop      13716.0            NaN
#                          Deaths/1M pop           464.0            NaN
#                          TotalTests         13206188.0            NaN
#                          Tests/1M pop          62085.0            NaN
#                          WHO Region           Americas            NaN
#
#                                            Population  TotalCases  NewCases  \
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop         NaN         NaN       NaN
#                          Deaths/1M pop            NaN         NaN       NaN
#                          TotalTests               NaN         NaN       NaN
#                          Tests/1M pop             NaN         NaN       NaN
#                          WHO Region               NaN         NaN       NaN
#               2917562    Country_Region           NaN         NaN       NaN
#                          Population               NaN         NaN       NaN
#                          TotalCases               NaN         NaN       NaN
#                          NewCases                 NaN         NaN       NaN
#                          TotalDeaths              NaN         NaN       NaN
#                          NewDeaths                NaN         NaN       NaN
#                          TotalRecovered           NaN         NaN       NaN
#                          NewRecovered             NaN         NaN       NaN
#                          ActiveCases              NaN         NaN       NaN
#                          Serious,Critical         NaN         NaN       NaN
#                          Tot Cases/1M pop         NaN         NaN       NaN
#                          Deaths/1M pop            NaN         NaN       NaN
#                          TotalTests               NaN         NaN       NaN
#                          Tests/1M pop             NaN         NaN       NaN
#                          WHO Region               NaN         NaN       NaN
#
#                                            TotalDeaths  NewDeaths  \
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop          NaN        NaN
#                          Deaths/1M pop             NaN        NaN
#                          TotalTests                NaN        NaN
#                          Tests/1M pop              NaN        NaN
#                          WHO Region                NaN        NaN
#               2917562    Country_Region            NaN        NaN
#                          Population                NaN        NaN
#                          TotalCases                NaN        NaN
#                          NewCases                  NaN        NaN
#                          TotalDeaths               NaN        NaN
#                          NewDeaths                 NaN        NaN
#                          TotalRecovered            NaN        NaN
#                          NewRecovered              NaN        NaN
#                          ActiveCases               NaN        NaN
#                          Serious,Critical          NaN        NaN
#                          Tot Cases/1M pop          NaN        NaN
#                          Deaths/1M pop             NaN        NaN
#                          TotalTests                NaN        NaN
#                          Tests/1M pop              NaN        NaN
#                          WHO Region                NaN        NaN
#
#                                            TotalRecovered  NewRecovered  \
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop             NaN           NaN
#                          Deaths/1M pop                NaN           NaN
#                          TotalTests                   NaN           NaN
#                          Tests/1M pop                 NaN           NaN
#                          WHO Region                   NaN           NaN
#               2917562    Country_Region               NaN           NaN
#                          Population                   NaN           NaN
#                          TotalCases                   NaN           NaN
#                          NewCases                     NaN           NaN
#                          TotalDeaths                  NaN           NaN
#                          NewDeaths                    NaN           NaN
#                          TotalRecovered               NaN           NaN
#                          NewRecovered                 NaN           NaN
#                          ActiveCases                  NaN           NaN
#                          Serious,Critical             NaN           NaN
#                          Tot Cases/1M pop             NaN           NaN
#                          Deaths/1M pop                NaN           NaN
#                          TotalTests                   NaN           NaN
#                          Tests/1M pop                 NaN           NaN
#                          WHO Region                   NaN           NaN
#
#                                            ActiveCases  Serious,Critical  \
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop          NaN               NaN
#                          Deaths/1M pop             NaN               NaN
#                          TotalTests                NaN               NaN
#                          Tests/1M pop              NaN               NaN
#                          WHO Region                NaN               NaN
#               2917562    Country_Region            NaN               NaN
#                          Population                NaN               NaN
#                          TotalCases                NaN               NaN
#                          NewCases                  NaN               NaN
#                          TotalDeaths               NaN               NaN
#                          NewDeaths                 NaN               NaN
#                          TotalRecovered            NaN               NaN
#                          NewRecovered              NaN               NaN
#                          ActiveCases               NaN               NaN
#                          Serious,Critical          NaN               NaN
#                          Tot Cases/1M pop          NaN               NaN
#                          Deaths/1M pop             NaN               NaN
#                          TotalTests                NaN               NaN
#                          Tests/1M pop              NaN               NaN
#                          WHO Region                NaN               NaN
#
#                                            Tot Cases/1M pop  Deaths/1M pop  \
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop               NaN            NaN
#                          Deaths/1M pop                  NaN            NaN
#                          TotalTests                     NaN            NaN
#                          Tests/1M pop                   NaN            NaN
#                          WHO Region                     NaN            NaN
#               2917562    Country_Region                 NaN            NaN
#                          Population                     NaN            NaN
#                          TotalCases                     NaN            NaN
#                          NewCases                       NaN            NaN
#                          TotalDeaths                    NaN            NaN
#                          NewDeaths                      NaN            NaN
#                          TotalRecovered                 NaN            NaN
#                          NewRecovered                   NaN            NaN
#                          ActiveCases                    NaN            NaN
#                          Serious,Critical               NaN            NaN
#                          Tot Cases/1M pop               NaN            NaN
#                          Deaths/1M pop                  NaN            NaN
#                          TotalTests                     NaN            NaN
#                          Tests/1M pop                   NaN            NaN
#                          WHO Region                     NaN            NaN
#
#                                            TotalTests  Tests/1M pop WHO Region
# Continent     TotalCases
# South America 455409     Tot Cases/1M pop         NaN           NaN        NaN
#                          Deaths/1M pop            NaN           NaN        NaN
#                          TotalTests               NaN           NaN        NaN
#                          Tests/1M pop             NaN           NaN        NaN
#                          WHO Region               NaN           NaN        NaN
#               2917562    Country_Region           NaN           NaN        NaN
#                          Population               NaN           NaN        NaN
#                          TotalCases               NaN           NaN        NaN
#                          NewCases                 NaN           NaN        NaN
#                          TotalDeaths              NaN           NaN        NaN
#                          NewDeaths                NaN           NaN        NaN
#                          TotalRecovered           NaN           NaN        NaN
#                          NewRecovered             NaN           NaN        NaN
#                          ActiveCases              NaN           NaN        NaN
#                          Serious,Critical         NaN           NaN        NaN
#                          Tot Cases/1M pop         NaN           NaN        NaN
#                          Deaths/1M pop            NaN           NaN        NaN
#                          TotalTests               NaN           NaN        NaN
#                          Tests/1M pop             NaN           NaN        NaN
#                          WHO Region               NaN           NaN        NaN

# %%
#Fait un groupement de continent en fonction du nombre de cas, du minimum, et du maximum des cas totaux
Lecture.groupby(['Continent']).TotalCases.agg([len, min, max])
# Out:
#                    len  min      max
# Continent
# Africa              57   10   538184
# Asia                48   20  2025409
# Australia/Oceania    6   22    19890
# Europe              48   12   871894
# North America       35   13  5032179
# South America       14   13  2917562

# %% [markdown]
# ### - Multi-indexes

# %%
essai_3 = Lecture.groupby(['Continent', 'Country_Region']).TotalCases.agg([len])
essai_3
# Out:
#                               len
# Continent     Country_Region
# Africa        Algeria           1
#               Angola            1
#               Benin             1
#               Botswana          1
#               Burkina Faso      1
# ...                           ...
# South America Paraguay          1
#               Peru              1
#               Suriname          1
#               Uruguay           1
#               Venezuela         1
#
# [208 rows x 1 columns]

# %%
#mi est multi-index
mi = essai_3.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
#reconversion en index normal
essai_3.reset_index()
# Out:
#          Continent Country_Region  len
# 0           Africa        Algeria    1
# 1           Africa         Angola    1
# 2           Africa          Benin    1
# 3           Africa       Botswana    1
# 4           Africa   Burkina Faso    1
# ..             ...            ...  ...
# 203  South America       Paraguay    1
# 204  South America           Peru    1
# 205  South America       Suriname    1
# 206  South America        Uruguay    1
# 207  South America      Venezuela    1
#
# [208 rows x 3 columns]

# %% [markdown]
# ### - Sorting (Tri) :
# Pour obtenir les données dans l'ordre souhaité, on utilise la méthode sort_values pour les trier.

# %%
#Groupements dans les colonnes Continent et Country_Region triées en fonction de leurs nombres de manière croissante.
essai_3 = essai_3.reset_index()
essai_3.sort_values(by = 'len').tail(20)
# Out:
#          Continent Country_Region  len
# 58            Asia        Armenia    1
# 59            Asia     Azerbaijan    1
# 60            Asia        Bahrain    1
# 61            Asia     Bangladesh    1
# 62            Asia         Bhutan    1
# 63            Asia        Brunei     1
# 64            Asia       Cambodia    1
# 65            Asia         Cyprus    1
# 66            Asia        Georgia    1
# 67            Asia      Hong Kong    1
# 68            Asia          India    1
# 69            Asia      Indonesia    1
# 70            Asia           Iran    1
# 71            Asia           Iraq    1
# 72            Asia         Israel    1
# 73            Asia          Japan    1
# 74            Asia         Jordan    1
# 75            Asia     Kazakhstan    1
# 206  South America        Uruguay    1
# 207  South America      Venezuela    1

# %%
#Groupements dans les colonnes Continent et Country_Region triées en fonction de leurs nombres de manière decroissante.
essai_3 = essai_3.reset_index()
essai_3.sort_values(by = 'len', ascending = False).tail(20)
# Out:
#          Continent Country_Region  len
# 57            Asia    Afghanistan    1
# 58            Asia        Armenia    1
# 59            Asia     Azerbaijan    1
# 60            Asia        Bahrain    1
# 61            Asia     Bangladesh    1
# 62            Asia         Bhutan    1
# 63            Asia        Brunei     1
# 65            Asia         Cyprus    1
# 76            Asia         Kuwait    1
# 66            Asia        Georgia    1
# 67            Asia      Hong Kong    1
# 68            Asia          India    1
# 69            Asia      Indonesia    1
# 70            Asia           Iran    1
# 71            Asia           Iraq    1
# 72            Asia         Israel    1
# 73            Asia          Japan    1
# 74            Asia         Jordan    1
# 75            Asia     Kazakhstan    1
# 207  South America      Venezuela    1

# %%
#tri par valeurs d'index de manière decroissante
essai_3.sort_index(ascending = False)
# Out:
#          Continent Country_Region  len
# 207  South America      Venezuela    1
# 206  South America        Uruguay    1
# 205  South America       Suriname    1
# 204  South America           Peru    1
# 203  South America       Paraguay    1
# ..             ...            ...  ...
# 4           Africa   Burkina Faso    1
# 3           Africa       Botswana    1
# 2           Africa          Benin    1
# 1           Africa         Angola    1
# 0           Africa        Algeria    1
#
# [208 rows x 3 columns]

# %%
#Tri par valeur de pays et nombre d'occurence dans les colonnes Continent et Country_Region
essai_3.sort_values(['Country_Region', 'len'])
# Out:
#     Continent  Country_Region  len
# 57       Asia     Afghanistan    1
# 111    Europe         Albania    1
# 0      Africa         Algeria    1
# 112    Europe         Andorra    1
# 1      Africa          Angola    1
# ..        ...             ...  ...
# 103      Asia         Vietnam    1
# 54     Africa  Western Sahara    1
# 104      Asia           Yemen    1
# 55     Africa          Zambia    1
# 56     Africa        Zimbabwe    1
#
# [208 rows x 3 columns]
